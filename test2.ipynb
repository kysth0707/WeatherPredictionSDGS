# %%
import numpy as np
from PIL import Image
import io
import cv2 as cv

# %%
with open('./testclouds/9.jpg', 'rb') as f:
	content = f.read()
np.array(Image.open(io.BytesIO(content)))
# Out:
# array([[[ 72, 134, 243],
#         [ 73, 135, 244],
#         [ 70, 132, 241],
#         ...,
#         [125, 173, 249],
#         [123, 171, 247],
#         [123, 171, 247]],
#
#        [[ 72, 134, 243],
#         [ 73, 135, 244],
#         [ 71, 133, 242],
#         ...,
#         [122, 170, 246],
#         [124, 172, 248],
#         [124, 172, 248]],
#
#        [[ 71, 133, 242],
#         [ 72, 134, 243],
#         [ 70, 134, 242],
#         ...,
#         [122, 170, 246],
#         [124, 172, 248],
#         [125, 173, 249]],
#
#        ...,
#
#        [[ 98, 159, 252],
#         [ 99, 160, 253],
#         [100, 161, 254],
#         ...,
#         [137, 193, 254],
#         [141, 195, 255],
#         [141, 195, 255]],
#
#        [[ 97, 158, 251],
#         [100, 161, 254],
#         [ 97, 160, 253],
#         ...,
#         [139, 195, 255],
#         [142, 196, 255],
#         [142, 196, 255]],
#
#        [[ 97, 158, 251],
#         [ 99, 160, 253],
#         [ 97, 160, 253],
# ...

# %%
cv.imread('./testclouds/9.jpg')
# Out:
# array([[[243, 134,  72],
#         [244, 135,  73],
#         [241, 132,  70],
#         ...,
#         [249, 173, 125],
#         [247, 171, 123],
#         [247, 171, 123]],
#
#        [[243, 134,  72],
#         [244, 135,  73],
#         [242, 133,  71],
#         ...,
#         [246, 170, 122],
#         [248, 172, 124],
#         [248, 172, 124]],
#
#        [[242, 133,  71],
#         [243, 134,  72],
#         [242, 134,  70],
#         ...,
#         [246, 170, 122],
#         [248, 172, 124],
#         [249, 173, 125]],
#
#        ...,
#
#        [[252, 159,  98],
#         [253, 160,  99],
#         [254, 161, 100],
#         ...,
#         [254, 193, 137],
#         [255, 195, 141],
#         [255, 195, 141]],
#
#        [[251, 158,  97],
#         [254, 161, 100],
#         [253, 160,  97],
#         ...,
#         [255, 195, 139],
#         [255, 196, 142],
#         [255, 196, 142]],
#
#        [[251, 158,  97],
#         [253, 160,  99],
#         [253, 160,  97],
# ...
